# %%
import cleaningData
import pandas as pd
import numpy as np

# %%
ticker = input()
# Out:
# azo

# %%
df = cleaningData.DataHandling.read_file(ticker)

# %%
df = cleaningData.DataHandling.clean_data(df)

# %%
df
# Out:
#                                    1990   1991     1992    1993     1994  \
# ROIC.AI | AZO
# Revenue                          672.00  818.0  1002.00  1217.0  1508.00
# COGS                             409.00  482.0   589.00   711.0   853.00
# Gross Profit                     263.00  336.0   413.00   506.0   655.00
# Gross Profit ratio                39.18   41.1    41.21    41.6    43.44
# Research and Development Exp.      0.00    0.0     0.00     0.0     0.00
# ...                                 ...    ...      ...     ...      ...
# Effect of Forex Changes on Cash    0.00    0.0     0.00     0.0     0.00
# Net Change In Cash                18.00   13.0    10.00    29.0    15.00
# Cash at the Beginning of Period    1.00    1.0     9.00    58.0    85.00
# Cash at the End of Period          0.00    0.0     0.00     0.0     0.00
# Free Cash Flow                    18.00    5.0    39.00     4.0    45.00
#
# ...
